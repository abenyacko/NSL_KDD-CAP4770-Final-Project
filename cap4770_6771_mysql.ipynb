# %%
# !python --version
# Out:
# Python 3.12.4

# %% [markdown]
# # MySQL connection with jupyter notebook

# %% [markdown]
# ### install mysql-connector-python

# %%
#mysql connection with python
# %conda install -c anaconda mysql-connector-python -y
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.1
#     latest version: 26.3.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - anaconda
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: c:\Users\andre\anaconda3
#
#   added / updated specs:
#     - mysql-connector-python
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mysql-connector-python-9.3.0|  py313h5da7b33_0         667 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         667 KB
#
# The following NEW packages will be INSTALLED:
#
#   mysql-connector-p~ anaconda/win-64::mysql-connector-python-9.3.0-py313h5da7b33_0
#
#
#
# Downloading and Extracting Packages: ...working...
# mysql-connector-pyth | 667 KB    |            |   0%
# mysql-connector-pyth | 667 KB    | 2          |   2%
# mysql-connector-pyth | 667 KB    | #1         |  12%
# mysql-connector-pyth | 667 KB    | #9         |  19%
# mysql-connector-pyth | 667 KB    | ##6        |  26%
# mysql-connector-pyth | 667 KB    | ###5       |  36%
# mysql-connector-pyth | 667 KB    | ####3      |  43%
# mysql-connector-pyth | 667 KB    | ####7      |  48%
# mysql-connector-pyth | 667 KB    | #####      |  50%
# mysql-connector-pyth | 667 KB    | #####7     |  58%
# mysql-connector-pyth | 667 KB    | #######1   |  72%
# mysql-connector-pyth | 667 KB    | ########1  |  82%
# mysql-connector-pyth | 667 KB    | #########3 |  94%
# mysql-connector-pyth | 667 KB    | ########## | 100%
# mysql-connector-pyth | 667 KB    | ########## | 100%
# mysql-connector-pyth | 667 KB    | ########## | 100%
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ### Connection with mysql

# %%
import mysql.connector as sql
conn = sql.connect(
    host='localhost', 
    user='root', 
    password='bob123',
    database= 'cap4770',  
    use_pure = True)

conn

# %%
cursor = conn.cursor(buffered=True)

# %%
cursor.execute("use cap4770")

# %%
cursor.execute("show tables")
for x in cursor:
    print(x)
# Out:
# ('customer',)
# ('flight_data',)
# ('flight_data_spring26',)
# ('test',)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# SQL query to fetch data from MySQL table
query = "select * from flight_data_spring26 limit 50000" #top 50k records of flight_data # actual dataset: ~ 1.8M records, 70 features 

# Fetch data into DataFrame
df = pd.read_sql(query, conn)
# Out:
# /var/folders/r4/yz3dd24127zb2x7mf_0wnfsj0lvwdn/T/ipykernel_3346/1329105515.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
df 
# df_first_50000 = df.head(50000)
# df_first_50000.to_csv('flight_data_since2018.csv', index=False)
# Out:
#        year  quarter  month  day_of_month  day_of_week     fl_date  \
# 0      2018        3      9             5            3  2018-09-05
# 1      2018        3      9             5            3  2018-09-05
# 2      2018        4     11            24            6  2018-11-24
# 3      2018        2      4            30            1  2018-04-30
# 4      2018        3      9             5            3  2018-09-05
# ...     ...      ...    ...           ...          ...         ...
# 49995  2018        3      9            24            1  2018-09-24
# 49996  2018        3      9            30            7  2018-09-30
# 49997  2018        3      9             4            2  2018-09-04
# 49998  2018        4     12             5            3  2018-12-05
# 49999  2018        2      4             5            4  2018-04-05
#
#       mkt_unique_carrier branded_code_share  mkt_carrier_airline_id  \
# 0                     AS                 AS                   19930
# 1                     AS                 AS                   19930
# 2                     NK                 NK                   20416
# 3                     UA       UA_CODESHARE                   19977
# 4                     AS                 AS                   19930
# ...                  ...                ...                     ...
# 49995                 AA       AA_CODESHARE                   19805
# 49996                 AA       AA_CODESHARE                   19805
# 49997                 AA       AA_CODESHARE                   19805
# 49998                 AA       AA_CODESHARE                   19805
# 49999                 UA       UA_CODESHARE                   19977
#
#       mkt_carrier  ...  distance_group carrier_delay  weather_delay nas_delay  \
# 0              AS  ...               6             0              0         0
# 1              AS  ...               7             0              0         0
# 2              NK  ...               6             0              0        29
# 3              UA  ...               4             0              0         0
# 4              AS  ...               7             0              0         0
# ...           ...  ...             ...           ...            ...       ...
# 49995          AA  ...               2             0              0         0
# 49996          AA  ...               2             0              0         0
# 49997          AA  ...               2             0              0         0
# 49998          AA  ...               3             0              0        29
# 49999          UA  ...               1             0              0         0
#
#       security_delay  late_aircraft_delay  div_airport_landings  total_delay  \
# 0                  0                    0                   0.0            5
# 1                  0                    0                   0.0            5
# 2                  0                    0                   0.0           58
# 3                  0                    0                   0.0            0
# 4                  0                    0                   0.0            0
# ...              ...                  ...                   ...          ...
# 49995              0                    0                   0.0           29
# 49996              0                    0                   0.0            0
# 49997              0                    0                   0.0            0
# 49998              0                    0                   0.0           58
# 49999              0                    0                   0.0            2
#
#             id total_delay_clf
# 0      3764035               1
# 1      3764044               1
# 2      5240494               1
# 3        90370               0
# 4      3764047               0
# ...        ...             ...
# 49995  3850803               1
# 49996  3850808               0
# 49997  3850812               0
# 49998  5351419               1
# 49999   199839               1
#
# [50000 rows x 70 columns]

# %%
# Close the MySQL connection
conn.close()
